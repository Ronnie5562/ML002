# %%
import pandas as pd

# %%
df = pd.read_csv("../../../dev_survey.csv") # This file is located in my desktop folder, but I dropped the zip in this directory.

# %%
# We can also read the data in another way and set our index from the data.
df2 = pd.read_csv("../../../dev_survey.csv", index_col="ResponseId")
# Looking at the result of df, Pandas added a first column of seria numbers that represents the index of each row.
# So, the code above specifies that the `ResponseId` column should serve as the index for each row.
# To go back to the pandas generated indexes, use: `.reset_index(inplace=True)` where `inplace=True` tells pandas to make the new index permanent. Although it can still be changed with `.set_index('The column you want to use for the indexing', inplace=True)`

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 72994       72995                     I am a developer by profession
# 72995       72996                     I am a developer by profession
# 72996       72997  I am not primarily a developer, but I write co...
# 72997       72998                     I am a developer by profession
# 72998       72999                     I am a developer by profession
#
#                 Employment                            RemoteWork  \
# 0                      NaN                                   NaN
# ...

# %%
df.shape # To get the (row, column) representation of the data
# Out:
# (72999, 79)

# %%
df.size
# Out:
# 5766921

# %%
df.info # To get a brief overview of the data.
# Out:
# <bound method DataFrame.info of        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 72994       72995                     I am a developer by profession
# 72995       72996                     I am a developer by profession
# 72996       72997  I am not primarily a developer, but I write co...
# 72997       72998                     I am a developer by profession
# 72998       72999                     I am a developer by profession
#
#                 Employment                            RemoteWork  \
# ...

# %%
df.info() # A table of the colums in the data, the number of data each column contains, and their data types.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72999 entries, 0 to 72998
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      72999 non-null  int64
#  1   MainBranch                      72999 non-null  object
#  2   Employment                      71451 non-null  object
#  3   RemoteWork                      58735 non-null  object
#  4   CodingActivities                58676 non-null  object
#  5   EdLevel                         71315 non-null  object
#  6   LearnCode                       71323 non-null  object
#  7   LearnCodeOnline                 50496 non-null  object
#  8   LearnCodeCoursesCert            29282 non-null  object
#  9   YearsCode                       71075 non-null  object
#  10  YearsCodePro                    51632 non-null  object
#  11  DevType                         61072 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 79) # Sets the maximum visible data to 79 columns max.
pd.set_option('display.max_rows', 80) # Sets the maximum visible data to 80 rows max.

# %%
schema_file = pd.read_csv("data/survey_results_schema.csv")

# %%
schema_file["question"]
# Out:
# 0     <div><span style="font-size:19px;"><strong>Hel...
# 1                                     Browser Meta Info
# 2     <span style="font-size:22px; font-family: aria...
# 3     Which of the following options best describes ...
# 4     Which of the following best describes your cur...
# 5     Which best describes your current work situation?
# 6     Which of the following best describes the code...
# 7     <span style="font-size:22px; font-family: aria...
# 8     Which of the following best describes the high...
# 9     How did you learn to code? Select all that apply.
# 10    What online resources do you use to learn to c...
# 11    What online courses or certifications do you u...
# 12    Including any education, how many years have y...
# 13    NOT including education, how many years have y...
# 14    Which of the following describes your current ...
# 15    Approximately how many people are employed by ...
# 16    What level of influence do you, personally, ha...
# ...

# %%
df.head(100)
# Out:
#     ResponseId                                         MainBranch  \
# 0            1                                      None of these
# 1            2                     I am a developer by profession
# 2            3  I am not primarily a developer, but I write co...
# 3            4                     I am a developer by profession
# 4            5                     I am a developer by profession
# ..         ...                                                ...
# 95          96                     I am a developer by profession
# 96          97                     I am a developer by profession
# 97          98                     I am a developer by profession
# 98          99                     I am a developer by profession
# 99         100                     I am a developer by profession
#
#                                            Employment  \
# 0                                                 NaN
# 1                                 Employed, full-time
# ...

# %%
df.shape
# Out:
# (72999, 79)

# %%
df['EdLevel']
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2          Master's degree (M.A., M.S., M.Eng., MBA, etc.)
# 3             Bachelor's degree (B.A., B.S., B.Eng., etc.)
# 4             Bachelor's degree (B.A., B.S., B.Eng., etc.)
#                                ...
# 72994      Master's degree (M.A., M.S., M.Eng., MBA, etc.)
# 72995      Master's degree (M.A., M.S., M.Eng., MBA, etc.)
# 72996                   Professional degree (JD, MD, etc.)
# 72997    Secondary school (e.g. American high school, G...
# 72998      Master's degree (M.A., M.S., M.Eng., MBA, etc.)
# Name: EdLevel, Length: 72999, dtype: object

# %%
df['EdLevel'].value_counts()
# Out:
# Bachelor's degree (B.A., B.S., B.Eng., etc.)                                          30156
# Master's degree (M.A., M.S., M.Eng., MBA, etc.)                                       15423
# Some college/university study without earning a degree                                 9297
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     7884
# Associate degree (A.A., A.S., etc.)                                                    2230
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             2167
# Primary/elementary school                                                              1799
# Something else                                                                         1241
# Professional degree (JD, MD, etc.)                                                     1118
# Name: EdLevel, dtype: int64

# %%
df.loc[0:10,'EdLevel'] # Don't wrap the first argument (row) when you're using slicing ":"
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2       Master's degree (M.A., M.S., M.Eng., MBA, etc.)
# 3          Bachelor's degree (B.A., B.S., B.Eng., etc.)
# 4          Bachelor's degree (B.A., B.S., B.Eng., etc.)
# 5       Master's degree (M.A., M.S., M.Eng., MBA, etc.)
# 6     Secondary school (e.g. American high school, G...
# 7     Some college/university study without earning ...
# 8       Master's degree (M.A., M.S., M.Eng., MBA, etc.)
# 9     Some college/university study without earning ...
# 10         Bachelor's degree (B.A., B.S., B.Eng., etc.)
# Name: EdLevel, dtype: object

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df.loc[:,'EdLevel':'LearnCodeCoursesCert']
# Out:
#                                                  EdLevel  \
# 0                                                    NaN
# 1                                                    NaN
# 2        Master's degree (M.A., M.S., M.Eng., MBA, etc.)
# 3           Bachelor's degree (B.A., B.S., B.Eng., etc.)
# 4           Bachelor's degree (B.A., B.S., B.Eng., etc.)
# ...                                                  ...
# 72994    Master's degree (M.A., M.S., M.Eng., MBA, etc.)
# 72995    Master's degree (M.A., M.S., M.Eng., MBA, etc.)
# 72996                 Professional degree (JD, MD, etc.)
# 72997  Secondary school (e.g. American high school, G...
# 72998    Master's degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                LearnCode  \
# 0                                                    NaN
# 1                                                    NaN
# 2      Books / Physical media;Friend or family member...
# ...

# %%
pd.set_option('display.max_rows', 80)

# %%
Countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Germany']
third_filt = ((df['CompTotal'] > 100000) & (df['Country'].isin(Countries)))

# %%
df.loc[high_salary, ['Country', 'EdLevel', 'YearsCodePro', 'DevType', 'CompTotal']]
# Out:
#        Country                                          EdLevel YearsCodePro  \
# 6676   Nigeria     Bachelor's degree (B.A., B.S., B.Eng., etc.)            4
# 6700   Nigeria     Bachelor's degree (B.A., B.S., B.Eng., etc.)            5
# 7102   Nigeria     Bachelor's degree (B.A., B.S., B.Eng., etc.)            4
# 8456   Nigeria  Master's degree (M.A., M.S., M.Eng., MBA, etc.)            2
# 8885   Nigeria     Bachelor's degree (B.A., B.S., B.Eng., etc.)            5
# ...        ...                                              ...          ...
# 71681  Nigeria     Bachelor's degree (B.A., B.S., B.Eng., etc.)            2
# 71846  Nigeria  Master's degree (M.A., M.S., M.Eng., MBA, etc.)            5
# 72016  Nigeria              Associate degree (A.A., A.S., etc.)            4
# 72180  Nigeria     Bachelor's degree (B.A., B.S., B.Eng., etc.)            5
# 72980  Nigeria     Bachelor's degree (B.A., B.S., B.Eng., etc.)            1
#
# ...
